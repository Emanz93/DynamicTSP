# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook

# %%
# costs: (10,)
# sols: (10, 232)
# times: (10,)
# p_bi: (10, 1000)
# p_gi: (10, 1000)
# n_bi: (10, 1000)
# n_gi: (10, 1000)
# ls_num_improvements: (10, 5, 1000)
# ls_rate_improvements: (10, 5, 1000)
# glob_best_change: (10, 1000)
# diversity: (10, 1000)
# avg_time: (10, 1000)
# best_performances: (1000,)
# avg_performances: (1000,)
# best_robusteness: (999,)
# avg_robusteness: (999,)

# %%
ir_saco_normal = np.load('../results/IR33_S_ACO_normal.npz')
ir_saco_ls = np.load('../results/IR33_S_ACO_ls.npz')
ir_saco_aio = np.load('../results/IR33_S_ACO_aio.npz')
ir_paco_normal = np.load('../results/IR33_P_ACO_normal.npz')
ir_paco_ls = np.load('../results/IR33_P_ACO_ls.npz')
ir_paco_aio = np.load('../results/IR33_P_ACO_aio.npz')

cos_saco_normal = np.load('../results/COS_S_ACO_normal.npz')
cos_saco_ls = np.load('../results/COS_S_ACO_ls.npz')
cos_saco_aio = np.load('../results/COS_S_ACO_aio.npz')
cos_paco_normal = np.load('../results/COS_P_ACO_normal.npz')
cos_paco_ls = np.load('../results/COS_P_ACO_ls.npz')
cos_paco_aio = np.load('../results/COS_P_ACO_aio.npz')

fen_saco_normal = np.load('../results/FEN1000_S_ACO_normal.npz')
fen_saco_ls = np.load('../results/FEN1000_S_ACO_ls.npz')
fen_saco_aio = np.load('../results/FEN1000_S_ACO_aio.npz')
fen_paco_normal = np.load('../results/FEN1000_P_ACO_normal.npz')
fen_paco_ls = np.load('../results/FEN1000_P_ACO_ls.npz')
fen_paco_aio = np.load('../results/FEN1000_P_ACO_aio.npz')

# %%
key = 'diversity'

# SACO - IR33
s = pd.Series(np.mean(ir_saco_normal['diversity'], axis=0))
print("ir_saco_normal_{} = {}".format(key, s.describe()))

s = pd.Series(np.mean(ir_saco_ls['diversity'], axis=0))
print("ir_saco_ls_{} = {}".format(key, s.describe()))

s = pd.Series(np.mean(ir_saco_aio['diversity'], axis=0))
print("ir_saco_aio_{} = {}".format(key, s.describe()))


# SACO - COS
s = pd.Series(np.mean(cos_saco_normal['diversity'], axis=0))
print("cos_saco_normal_{} = {}".format(key, s.describe()))

s = pd.Series(np.mean(cos_saco_ls['diversity'], axis=0))
print("cos_saco_ls_{} = {}".format(key, s.describe()))

s = pd.Series(np.mean(cos_saco_aio['diversity'], axis=0))
print("cos_saco_aio_{} = {}".format(key, s.describe()))

# SACO - FEN
s = pd.Series(np.mean(fen_saco_normal['diversity'], axis=0))
print("fen_saco_normal_{} = {}".format(key, s.describe()))

s = pd.Series(np.mean(fen_saco_ls['diversity'], axis=0))
print("fen_saco_ls_{} = {}".format(key, s.describe()))

s = pd.Series(np.mean(fen_saco_aio['diversity'], axis=0))
print("fen_saco_aio_{} = {}".format(key, s.describe()))


# PACO - IR33
print("ir_paco_normal_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
x = ir_paco_ls['ls_rate_improvements']
print("ir_paco_ls_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
x = ir_paco_aio['ls_rate_improvements']
print("ir_paco_aio_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
# PACO - COS
print("cos_paco_normal_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
x = cos_paco_ls['ls_rate_improvements']
print("cos_paco_ls_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
x = cos_paco_aio['ls_rate_improvements']
print("cos_paco_aio_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
# PACO - FEN
print("fen_paco_normal_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
x = fen_paco_ls['ls_rate_improvements']
print("fen_paco_ls_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
x = fen_paco_aio['ls_rate_improvements']
print("fen_paco_aio_{} = {}".format(key, np.mean(x[np.nonzero(x)])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b34252c7eed4> in <module>()
#       2
#       3 # SACO - IR33
# ----> 4 s = pd.Series(np.mean(ir_saco_normal['diversity'], axis=0))
#       5 print("ir_saco_normal_{} = {}".format(key, s.describe()))
#       6
#
# NameError: name 'ir_saco_normal' is not defined

# %%
s = pd.Series(np.mean(ir_saco_ls['diversity'], axis=0))
s.describe()
#run_avg = np.mean(np.mean(np.mean(, axis=0), axis=0), axis=0)
# Out:
# count    1000.000000
# mean        0.996852
# std         0.003626
# min         0.972759
# 25%         0.995517
# 50%         0.998362
# 75%         0.999310
# max         1.000000
# dtype: float64

# %%
ir_33_saco = ir_saco_normal['glob_best_change']
ir_33_paco = ir_paco_normal['glob_best_change']
cos_33_saco = cos_saco_normal['glob_best_change']
cos_33_paco = cos_paco_normal['glob_best_change']
fen_33_saco = fen_saco_normal['glob_best_change']
fen_33_paco = fen_paco_normal['glob_best_change']

x = list(range(1000))
plt.title("Ir33: best-solution-so-far change")
plt.xlabel("Generations")
plt.ylabel("Tour Cost")
plt.plot(x, ir_33_saco[1], label='IR33 - ACO')
plt.plot(x, ir_33_paco[0], label='IR33 - P-ACO')
plt.plot(x, cos_33_saco[1], label='COS - ACO')
plt.plot(x, cos_33_paco[0], label='COS - P-ACO')
plt.plot(x, fen_33_saco[0], label='FEN - ACO')
plt.plot(x, fen_33_paco[0], label='FEN - P-ACO')
plt.legend(loc='upper right', bbox_to_anchor=(1, 0.78))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Analyzing cost sols and times.

# %%
best_performances = loaded['best_performances']
avg_performances = loaded['avg_performances']
best_robusteness = loaded['best_robusteness']
avg_robusteness = loaded['avg_robusteness']

# %%
len(best_performances)
# Out:
# 1000

# %%
# plot the best_performance.
best_idx = np.argmin(best_performances)
best = best_performances[best_idx]
print('{} {}'.format(best, best_idx))

figure()
y = list(range(len(best_performances)))
plot(best_performances)
title("P_best")
xlabel("Iterations")
plot( best_idx, best, 'r.', label='best')
# Out:
# 84877.53917996638 702
# <img src="data:image/png;base64,..." width="640">

# %%
# plot the best_performance.
figure()
y = list(range(len(avg_performances)))
plot(avg_performances)
title("P_best")
xlabel("Iterations")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Iterations')

# %%
# plot the best_performance.
figure()
y = list(range(len(best_performances)))
plot(best_performances)
title("P_best")
xlabel("Iterations")

# %%
x = ir_saco_ls['diversity']
avg = np.mean(x, axis=0)
plt.plot(avg)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
x = ir_saco_aio['p_bi']
x = np.mean(x, axis=0)
np.shape(x)
plt.plot(x)
plt.title("p(bi) plot over the generations")
plt.ylabel("p(bi)")
plt.xlabel("generations")
# Out:
# Text(0.5,0,'generations')
